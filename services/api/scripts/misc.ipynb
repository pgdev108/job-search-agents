# %%
import pandas as pd

# %%
import asyncio

# %%
from sqlalchemy import select
from app.db.session import AsyncSessionLocal
from app.db.init_db import init_db
from app.models.company import Company

async def fetch():
    await init_db()
    async with AsyncSessionLocal() as session:
        result = await session.execute(select(Company.name)
                                       .where(Company.website.is_(None))
                                       .order_by(Company.name))
        return result.all()
    
rows = await fetch()
print(f"Comapnies without website: {len(rows)} ")
# Out:
# Comapnies without website: 2381

# %%
df = pd.DataFrame(rows, columns=['name'])
df.head()
# Out:
#                          name
# 0           1-800 Flowers.Com
# 1             1St Source Corp
# 2                      2U Inc
# 3                          3M
# 4  6D Global Technologies Inc

# %%
output_path = '/Users/pankaj/workspace/ai-projects/ed/job-search-agents/services/api/data/companies_without_website.csv'
df.to_csv(output_path, index=False)
